# %%
import os
os.environ['OPEN_CATALOG_SPARK_CRED'] = '8fechlqm2Pn1mARRM6a+uTVl2Sk=:HJMbgYz5dIpG1i6xQ9zSKCdi95iDShte2PLtJwJfjd0='

import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('hol-demo') \
    .config('spark.driver.host', 'localhost') \
    .config('spark.jars.packages', 'org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.6.1,software.amazon.awssdk:bundle:2.20.160') \
    .config('spark.sql.extensions', 'org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions') \
    .config('spark.sql.defaultCatalog', 'open_catalog') \
    .config('spark.sql.catalog.open_catalog', 'org.apache.iceberg.spark.SparkCatalog') \
    .config('spark.sql.catalog.open_catalog.type', 'rest') \
    .config('spark.sql.catalog.open_catalog.uri','https://PMKJSNQ-DECONNECT_HOL_DEMO.snowflakecomputing.com/polaris/api/catalog') \
    .config('spark.sql.catalog.open_catalog.credential', '8fechlqm2Pn1mARRM6a+uTVl2Sk=:HJMbgYz5dIpG1i6xQ9zSKCdi95iDShte2PLtJwJfjd0=') \
    .config('spark.sql.catalog.open_catalog.header.X-Iceberg-Access-Delegation','vended-credentials') \
    .config('spark.sql.catalog.open_catalog.warehouse','external_catalog_snowflake') \
    .config('spark.sql.catalog.open_catalog.scope','PRINCIPAL_ROLE:ALL')\
    .config('spark.sql.catalog.open_catalog.client.region','us-west-2')\
    .config("spark.sql.iceberg.vectorization.enabled", "false")\
    .getOrCreate()

print('Spark is running')
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# Cell In[3], line 21
#      17     .config('spark.sql.catalog.open_catalog.warehouse','external_catalog_snowflake') \
#      18     .config('spark.sql.catalog.open_catalog.scope','PRINCIPAL_ROLE:ALL')\
#      19     .config('spark.sql.catalog.open_catalog.client.region','us-west-2')\
#      20     .config("spark.sql.iceberg.vectorization.enabled", "false")\
# ---> 21     .getOrCreate()
#      22
#      23 print('Spark is running')
#
# File c:\Users\Krish Kabi\Documents\Data & AI Projects Courses\Projects\Snowflake Projects\Snowflake Lakehouse Project\deconnect-hol-demo\Lib\site-packages\pyspark\sql\session.py:557, in SparkSession.Builder.getOrCreate(self)
#     555     sparkConf.set(key, value)
#     556 # This SparkContext may be an existing one.
# --> 557 sc = SparkContext.getOrCreate(sparkConf)
#     558 # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559 # by all sessions.
#     560 session = SparkSession(sc, options=self._options)
#
# File c:\Users\Krish Kabi\Documents\Data & AI Projects Courses\Projects\Snowflake Projects\Snowflake Lakehouse Project\deconnect-hol-demo\Lib\site-packages\pyspark\core\context.py:542, in SparkContext.getOrCreate(cls, conf)
#     540 with SparkContext._lock:
#     541     if SparkContext._active_spark_context is None:
# --> 542         SparkContext(conf=conf or SparkConf())
#     543     assert SparkContext._active_spark_context is not None
#     544     return SparkContext._active_spark_context
#
# File c:\Users\Krish Kabi\Documents\Data & AI Projects Courses\Projects\Snowflake Projects\Snowflake Lakehouse Project\deconnect-hol-demo\Lib\site-packages\pyspark\core\context.py:206, in SparkContext.__init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls, udf_profiler_cls, memory_profiler_cls)
#     200 if gateway is not None and gateway.gateway_parameters.auth_token is None:
#     201     raise ValueError(
#     202         "You are trying to pass an insecure Py4j gateway to Spark. This"
#     203         " is not allowed as it is a security risk."
#     204     )
# --> 206 SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     207 try:
#     208     self._do_init(
#     209         master,
#     210         appName,
#    (...)    220         memory_profiler_cls,
#     221     )
#
# File c:\Users\Krish Kabi\Documents\Data & AI Projects Courses\Projects\Snowflake Projects\Snowflake Lakehouse Project\deconnect-hol-demo\Lib\site-packages\pyspark\core\context.py:463, in SparkContext._ensure_initialized(cls, instance, gateway, conf)
#     461 with SparkContext._lock:
#     462     if not SparkContext._gateway:
# --> 463         SparkContext._gateway = gateway or launch_gateway(conf)
#     464         SparkContext._jvm = SparkContext._gateway.jvm
#     466     if instance:
#
# File c:\Users\Krish Kabi\Documents\Data & AI Projects Courses\Projects\Snowflake Projects\Snowflake Lakehouse Project\deconnect-hol-demo\Lib\site-packages\pyspark\java_gateway.py:111, in launch_gateway(conf, popen_kwargs)
#     108     time.sleep(0.1)
#     110 if not os.path.isfile(conn_info_file):
# --> 111     raise PySparkRuntimeError(
#     112         errorClass="JAVA_GATEWAY_EXITED",
#     113         messageParameters={},
#     114     )
#     116 with open(conn_info_file, "rb") as info:
#     117     gateway_port = read_int(info)
#
# PySparkRuntimeError: [JAVA_GATEWAY_EXITED] Java gateway process exited before sending its port number.
